# %% [markdown]
# ## CAPSTONE PROJECT- MAY 2024

# %% [markdown]
# ### _DATA ANALYSIS IN MICROSOFT POWER BI ON NORTHWIND DATABASE_

# %% [markdown]
# # NorthWind Company's Sales, Product and Customer Performance Report

# %%
from IPython.display import Image
file_path = "C:/Users/brnersr/Desktop/Capstone_Northwind_PB/NW1.png"
Image(filename=file_path)

# %%
from IPython.display import Image
file_path = "C:/Users/brnersr/Desktop/Capstone_Northwind_PB/NW1_1.png"
Image(filename=file_path)

# %% [markdown]
# This visual represents the NorthWind Company's Sales, Product and Customer Performance Report
#
# The data set starts from July 1996 and lasts until April 1998. Therefore, it is not possible to make a clear assessment for growth rates and turnover values.
#
# Number of Orders: The number of orders in 1996 was 152, which increased by 168% to 408 in 1997. However, it decreased by 33% to 270 in 1998. In total, there were 830 orders.
#
# Number of Products Sold: The number of products sold in 1996 was 10 billion, which increased by 166% to 25 billion in 1997. It then decreased by 36% to 16 billion in 1998. Overall, 51 billion products were sold.
#
# Turnover: The turnover in 1996 was 208 million, which increased by 196% to 617 million in 1997. It then decreased by 28.6% to  441 million in 1998. The total turnover was  1.27 billion.
#
# Number of Countries: The company received orders from 21 different countries. The top five countries with the most orders were the USA (49), Sweden (37), and Austria (30).
#
# Most Used Shipping Company: United Package was the most used shipping company, handling 326 orders.
#
# Target and Realized Orders: Out of a target of 1000 orders, 830 were realized. Product sales target and turnover target have been achieved.
#
# Customer: Since 25.84% of customers are hibernating, campaigns are needed to win them back.

# %%
from IPython.display import Image
file_path = "C:/Users/brnersr/Desktop/Capstone_Northwind_PB/NW2.png"
Image(filename=file_path)

# %% [markdown]
# Based on this information, we can conclude that the "Beverages" category in particular has shown significant fluctuations in monthly earnings, with peaks in certain months indicating high demand or successful sales strategies during those periods.
#
# A comparison of annual earnings across different product categories shows a shift in the top earning categories from 1996 to 1998. In more detail, in 1996 the highest earning product category was "Beverages", while in 1997 it was Dairy Products.

# %%
from IPython.display import Image
file_path = "C:/Users/brnersr/Desktop/Capstone_Northwind_PB/NW3.png"
Image(filename=file_path)

# %% [markdown]
# The earnings data for "Chai" highlights the variability in its monthly performance, with significant peaks and troughs that could be analyzed to identify underlying factors driving these changes.
#
# The earnings for Chai show significant fluctuations over the months from October 1996 to April 1998.
# Peaks are observed in January 1998 (1.741B) and October 1997 (1.548B).
# The lowest earnings were in July 1997 (122M) and April 1998 (612M).
# The total earnings for Chai over this period amounted to 12.79 billion.
#
# The order distribution data showcases. The highest number of orders was in the "Beverages" category (3,384), followed by "Confections" (2,908) and "Condiments" (2,034). The most popular product belong to "Beverages".

# %%
from IPython.display import Image
file_path = "C:/Users/brnersr/Desktop/Capstone_Northwind_PB/NW4.png"
Image(filename=file_path)

# %% [markdown]
# The USA has the highest number of product orders, significantly leading other countries.
# Austria, France, and Canada also show a substantial number of product orders.
# The graph indicates a sharp drop in orders as we move from the USA to other countries, with Belgium, Mexico, Spain, and Brazil having moderate order numbers.
# Countries like the UK, Italy, Germany, and Sweden have the fewest product orders, indicating potentially smaller markets or less demand.
#
# These insights highlight the USA as the dominant market for Alice Mutton, followed by European countries like Austria and Canada. Venezuela shows a high diversity in product orders and significant earnings across various product categories, making it a key market for NorthWind's categorical product sales.

# %%
from IPython.display import Image
file_path = "C:/Users/brnersr/Desktop/Capstone_Northwind_PB/NW5.png"
Image(filename=file_path)

# %% [markdown]
# Shipping Performance by Country:
#
# The dashboard shows a drop-down filter for selecting a country. Here, "Mexico" is selected.
#
# Federal Shipping has an average delivery time of 8 days.
# Speedy Express and United Package have delivery times of 10 and 11 days, respectively.
#
# The table in the center displays the fastest shipping deliveries by category for the selected country (Mexico). Federal Shipping and United Package both deliver Condiments in Mexico.
#
# Shipping Company Priorities:
#
# The "Shipping Company Priorities of Countries" table ranks the number of orders handled by each shipping company in various countries.
# Germany has a total of 122 orders distributed among Federal Shipping (28), Speedy Express (41), and United Package (53).
# The USA also has a total of 122 orders with 40 handled by Federal Shipping, 31 by Speedy Express, and 51 by United Package.
#
# Comparison of Average Delivery and Number of Orders by Country:
#
# The bar chart at the bottom compares the average delivery times and the number of orders by country. The USA and Germany have the highest number of orders (122 each), with varying average delivery speeds.
#
# United Package handles the highest number of orders overall (326).
# Countries like the USA and Germany have high shipping activities with 122 orders each, indicating significant shipping traffic.
# The average delivery times and shipping priorities vary significantly across different countries and companies, providing opportunities for optimizing logistics and improving delivery performance.

# %%
from IPython.display import Image
file_path = "C:/Users/brnersr/Desktop/Capstone_Northwind_PB/NW6.png"
Image(filename=file_path)

# %% [markdown]
# Customer Segmentation:
# A significant portion of customers (26%) are in the "Hibernating" segment, indicating inactive customers who may need re-engagement strategies.
# Loyal Customers make up 19%, representing a strong base of repeat buyers.
#
# Sales Performance by Day:
# Friday is the most profitable day of the week, suggesting a peak in customer purchases at the end of the work week.
# Consistent order counts across days indicate a stable sales volume throughout the week.
#
# Customer Engagement:
# The presence of registered customers who have never ordered suggests a potential area for targeted marketing efforts to convert these registrations into actual sales.
#
# Customer Target Achievement:
# The current number of customers exceeds the target, which is a positive indicator of customer acquisition efforts.

# %%
from IPython.display import Image
file_path = "C:/Users/brnersr/Desktop/Capstone_Northwind_PB/NW7.png"
Image(filename=file_path)

# %% [markdown]
# Stock Value and Quantity Distribution:
# "Seafood" and "Beverages" categories have the highest stock quantities, indicating strong inventory levels.
# "Condiments" and "Dairy Products" also have significant stock levels, suggesting these are important categories for the business. "Produce" has the lowest stock value and quantity, indicating either less demand or a more perishable nature.
#
# Inventory Turnover:
# "Grandma’s Boysenberry Spread" has the highest ITR (0.40), indicating it sells and replenishes more frequently than other products. "Genen Shouy"u and "Sirop d'érable" also have relatively high ITRs, suggesting they are popular and fast-moving items.
# Products like "Chef Anton's Cajun Seasoning" and "Louisiana Fiery Hot Pepper Sauce" have lower ITRs, indicating slower turnover and potentially excess inventory.
#
# Discontinued Products:
# Monitoring discontinued products is essential as they impact inventory and sales strategies. Ensuring discontinued items are cleared from stock can prevent obsolescence and free up storage space.
#
# Price and Discount Management:
# Understanding the max discount percentage helps in planning promotional strategies while maintaining profitability. Products with higher discounts can be targeted for sales events to boost movement.
#
# For categories with high stock levels but low ITR, consider promotional strategies to boost sales and reduce excess inventory.
# Evaluate the need for high stock levels in categories with low turnover to minimize holding costs.
#
# Products with high ITR should be prioritized in marketing and sales efforts to leverage their popularity.
# Ensure sufficient stock for fast-moving items to avoid stockouts and lost sales.

# %%
from IPython.display import Image
file_path = "C:/Users/brnersr/Desktop/Capstone_Northwind_PB/COHORT.png"
Image(filename=file_path)
